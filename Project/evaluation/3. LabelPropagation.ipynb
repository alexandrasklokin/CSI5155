# %%
import pandas as pd
import numpy as np
import sklearn
import ipynb

from sklearn.metrics import accuracy_score,f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
from ipynb.fs.full.Metrics import Evaluation
from ipynb.fs.full.Metrics import ROCcurve

# %%
filename1 = 'online_shoppers_intentions'
df1r = pd.read_csv("../pred/labelpropagation/noresampling/"+filename1+".csv", index_col=0)
df1u = pd.read_csv("../pred/labelpropagation/undersampled/"+filename1+".csv", index_col=0)
df1o = pd.read_csv("../pred/labelpropagation/oversampled/"+filename1+".csv", index_col=0)
df1r_time = pd.read_csv("../pred/labelpropagation/noresampling/"+filename1+"_time.csv", index_col=0)
df1u_time = pd.read_csv("../pred/labelpropagation/undersampled/"+filename1+"_time.csv", index_col=0)
df1o_time = pd.read_csv("../pred/labelpropagation/oversampled/"+filename1+"_time.csv", index_col=0)

filename2 = 'marketing_campaign'
df2r = pd.read_csv("../pred/labelpropagation/noresampling/"+filename2+".csv", index_col=0)
df2u= pd.read_csv("../pred/labelpropagation/undersampled/"+filename2+".csv", index_col=0)
df2o = pd.read_csv("../pred/labelpropagation/oversampled/"+filename2+".csv", index_col=0)
df2r_time = pd.read_csv("../pred/labelpropagation/noresampling/"+filename2+"_time.csv", index_col=0)
df2u_time = pd.read_csv("../pred/labelpropagation/undersampled/"+filename2+"_time.csv", index_col=0)
df2o_time = pd.read_csv("../pred/labelpropagation/oversampled/"+filename2+"_time.csv", index_col=0)


filename3 = 'heart'
df3r = pd.read_csv("../pred/labelpropagation/noresampling/"+filename3+".csv", index_col=0)
df3u = pd.read_csv("../pred/labelpropagation/undersampled/"+filename3+".csv", index_col=0)
df3o = pd.read_csv("../pred/labelpropagation/oversampled/"+filename3+".csv", index_col=0)
df3r_time = pd.read_csv("../pred/labelpropagation/noresampling/"+filename3+"_time.csv", index_col=0)
df3u_time = pd.read_csv("../pred/labelpropagation/undersampled/"+filename3+"_time.csv", index_col=0)
df3o_time = pd.read_csv("../pred/labelpropagation/oversampled/"+filename3+"_time.csv", index_col=0)

# %%
Evaluation(df1r, df1u, df1o, df1r_time, df1u_time, df1o_time, filename1, 'labelpropagation')
Evaluation(df2r, df2u, df2o, df2r_time, df2u_time, df2o_time, filename2, 'labelpropagation')
Evaluation(df3r, df3u, df3o, df3r_time, df3u_time, df3o_time, filename3, 'labelpropagation')
# Out:
# ___________________________________________________________________:0
# ___________________________________________________________________:10
# ___________________________________________________________________:20
# ___________________________________________________________________:50
# ___________________________________________________________________:90
# ___________________________________________________________________:95
# ___________________________________________________________________:0
# ___________________________________________________________________:10
# ___________________________________________________________________:20
# ___________________________________________________________________:50
# ___________________________________________________________________:90
# ___________________________________________________________________:95
# ___________________________________________________________________:0
# ...

# %%
ROCcurve(df1r, 'noresampling', filename1, 'labelpropagation')
ROCcurve(df1u, 'undersampling', filename1, 'labelpropagation')
ROCcurve(df1o, 'oversampling', filename1, 'labelpropagation')

# %%
ROCcurve(df2r, 'noresampling', filename2, 'labelpropagation')
ROCcurve(df2u, 'undersampling', filename2, 'labelpropagation')
ROCcurve(df2o, 'oversampling', filename2, 'labelpropagation')

# %%
ROCcurve(df3r, 'noresampling', filename3, 'labelpropagation')
ROCcurve(df3u, 'undersampling', filename3, 'labelpropagation')
ROCcurve(df3o, 'oversampling', filename3, 'labelpropagation')
